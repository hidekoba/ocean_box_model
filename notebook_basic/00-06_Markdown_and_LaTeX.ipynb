# %% [markdown]
# # 00-06. Markdown & LaTeX
# # Markdown と LaTeX 入門
#
# ## Goals
#
# Jupyter Notebook の Markdown と LaTeX を使って、
# 読みやすい科学ノートを書く方法を学びます。
#
# Topics
# - headings
# - lists
# - tables
# - links
# - images
# - code blocks
# - inline equations
# - display equations
# - scientific writing

# %% [markdown]
# ## 1. Headings
#
# ```markdown
# # Title
# ## Section
# ### Subsection
# ```

# %% [markdown]
# ## 2. Lists
#
# ```markdown
# - Item 1
# - Item 2
#
# 1. First
# 2. Second
# ```

# %% [markdown]
# ## 3. Tables
#
# ```markdown
# | Variable | Unit |
# |---|---|
# | Temperature | °C |
# | Salinity | PSU |
# ```

# %% [markdown]
# ## 4. LaTeX
#
# Inline:
#
# ```markdown
# \(E=mc^2\)
# ```
#
# Display:
#
# ```markdown
# \[
# C\frac{dT}{dt}=F-\lambda T
# \]
# ```
#
# Chemical species:
#
# \[
# \mathrm{CO_2},\;
# \mathrm{O_2},\;
# \mathrm{PO_4}
# \]

# %% [markdown]
# ## 5. Code blocks
#
# ````markdown
# ```python
# print("Hello")
# ```
# ````

# %% [markdown]
# ## 6. Links
#
# ```markdown
# [GitHub](https://github.com)
# ```

# %% [markdown]
# ## 7. Images
#
# ```markdown
# ![Figure](figure.png)
# ```

# %% [markdown]
# ## 8. Good notebook structure
#
# ```text
# Title
# Goal
# Theory
# Code
# Figures
# Discussion
# Exercises
# Summary
# ```

# %% [markdown]
# ## Hands-on 1
#
# Markdown を使って
#
# - タイトル
# - 自己紹介
# - 箇条書き
# - 表
#
# を作成してください。

# %% [markdown]
# ## Hands-on 2
#
# 次の式を Markdown で書いてください。
#
# \[
# \frac{dC}{dt}=F_{\mathrm{in}}-F_{\mathrm{out}}
# \]

# %% [markdown]
# ## Scientific writing tips
#
# - 目的を書く
# - 単位を書く
# - 図にはタイトルと軸ラベル
# - 結果だけでなく考察を書く
# - Notebook は上から Run All できるようにする

# %%
# Python code can appear between Markdown sections.
print("Markdown and Python work together!")

# %% [markdown]
# ## Summary
#
# 学んだ内容
#
# - Markdown
# - LaTeX
# - Tables
# - Links
# - Images
# - Code blocks
# - Scientific notebook writing
#
# Next:
#
# **00-07 Debugging**
