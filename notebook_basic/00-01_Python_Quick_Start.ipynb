# %% [markdown]
# # 00-01. Python Quick Start
# # Python 基礎
#
# ## Goals / 目的
#
# Python の基本文法を学びます。
#
# Topics:
# - numbers
# - strings
# - lists
# - dictionaries
# - if
# - for
# - functions
#
# 日英併記・Hands-on 形式です。

# %%
print("Welcome to Python!")

# %% [markdown]
# ## 1. Numbers / 数値

# %%
a=10
b=3
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a**2)

# %% [markdown]
# ## 2. Strings / 文字列

# %%
name="Ocean"
print("Hello",name)
print(name.upper())
print(len(name))

# %% [markdown]
# ## 3. Lists / リスト

# %%
temperature=[20,15,8,4,2]
print(temperature)
print(temperature[0])
print(temperature[-1])
print(sum(temperature)/len(temperature))

# %% [markdown]
# ## Hands-on 1
#
# リスト `depth=[0,100,500,1000]` を作り、最大値を表示してください。

# %%
depth=[0,100,500,1000]
# Write your code here

# %% [markdown]
# ## 4. Dictionaries / 辞書

# %%
box={"P":"Pacific","A":"Atlantic Deep","D":"Deep"}
print(box)
print(box["A"])

# %% [markdown]
# ## 5. if 文 / if statement

# %%
temperature=18
if temperature>15:
    print("Warm")
else:
    print("Cold")

# %% [markdown]
# ## 6. for ループ / for loop

# %%
for i in range(5):
    print(i)

# %%
for t in [20,15,8,4]:
    print(t)

# %% [markdown]
# ## 7. 関数 / Functions

# %%
def area_circle(r):
    import math
    return math.pi*r**2

print(area_circle(3))

# %% [markdown]
# ## Hands-on 2
#
# 半径 5 の円の面積を関数で計算してください。

# %%
# Write your code here

# %% [markdown]
# ## 8. NumPy の準備 / Preparing for NumPy

# %%
import numpy as np
x=np.arange(5)
print(x)
print(x*2)

# %% [markdown]
# ## 9. Mini Exercise
#
# 水温リストの平均を求めてください。
#
# ```python
# temp=[20,18,15,10,5]
# ```

# %%
temp=[20,18,15,10,5]
# Calculate the mean

# %% [markdown]
# ## 10. Summary / まとめ
#
# 学んだ内容
#
# - 数値
# - 文字列
# - リスト
# - 辞書
# - if
# - for
# - 関数
# - NumPy の導入
#
# 次は **00-02 NumPy 入門** です。
