# %% [markdown]
# # Two-box ocean model (Colab)
# This notebook runs the `two_box.py` model and displays results in a pandas DataFrame.
# Make sure the repository is available in the notebook (e.g. `git clone` or upload files).

# %%
# Install dependencies
# !pip install -q -r requirements.txt

# %%
# Run the model and show results
import two_box
out = two_box.run_model(verbose=False)
import pandas as pd
df = two_box.create_dataframe(out, box1_name='SDA', box2_name='DPA')
df
