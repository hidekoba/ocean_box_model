# %% [markdown]
# # 05-08. PSLNMD Summary and Integrated Exercises
#
# **Ocean Box Modeling with Python / 海洋ボックスモデル入門**
#
# ## 今日の目的 / Goals
# - PSLNMD モデル全体を復習する / Review the complete PSLNMD model.
# - 輸送・Ideal Age・炭素循環・同位体を結び付ける / Connect transport, Ideal Age, the carbon cycle, and isotopes.
# - 06 (PSLNMAD) へ進む準備をする / Prepare for the PSLNMAD model.

# %% [markdown]
# ## 1. PSLNMD の全体像 / Overview of PSLNMD
#
# ```text
# N → M → D → S → P → L → N
# ```
#
# この循環により、表層・中層・深層が結ばれます。
#
# This circulation links the surface, intermediate, and deep ocean.

# %%
import matplotlib.pyplot as plt

fig,ax=plt.subplots(figsize=(8,5))
pos={'P':(0.1,0.7),'S':(0.3,0.7),'L':(0.5,0.7),'N':(0.8,0.7),'M':(0.5,0.42),'D':(0.5,0.15)}
for k,(x,y) in pos.items():
    ax.text(x,y,k,ha='center',va='center',bbox=dict(boxstyle='round',fc='white'))
path=[('N','M'),('M','D'),('D','S'),('S','P'),('P','L'),('L','N')]
for a,b in path:
    ax.annotate('',xy=pos[b],xytext=pos[a],arrowprops=dict(arrowstyle='->'))
ax.set_xlim(0,1);ax.set_ylim(0,1);ax.axis('off')
plt.show()

# %% [markdown]
# ## 2. ここまでに学んだこと / What you have learned
#
# 1. Transport matrix / 輸送行列
# 2. Passive tracer / 保存トレーサー
# 3. Origin tracer / 起源トレーサー
# 4. Ideal Age
# 5. Carbon cycle (DIC, PO4, O2)
# 6. δ13C and Δ14C

# %% [markdown]
# ## 3. Concepts are connected / 概念のつながり
#
# ```text
# Transport
#    ↓
# Tracer
#    ↓
# Ideal Age
#    ↓
# Carbon Cycle
#    ↓
# δ13C / Δ14C
# ```

# %% [markdown]
# ## 4. 総合演習 / Integrated exercises
#
# ### Exercise 1
# なぜ輸送行列を使うのか説明しなさい。
#
# Explain why we use a transport matrix.
#
# ### Exercise 2
# N に入れた染料が D に届く理由を説明しなさい。
#
# Explain why dye released in N reaches D.
#
# ### Exercise 3
# Ideal Age が大きいほど Δ14C が低くなる理由を説明しなさい。
#
# Explain why larger Ideal Age corresponds to lower Δ14C.
#
# ### Exercise 4
# 生物ポンプは DIC・PO4・O2 をどのように変化させるか説明しなさい。
#
# Explain how the biological pump changes DIC, PO4, and O2.
#
# ### Exercise 5
# PSLNMD の限界は何か。PSLNMAD では何を改善するのか。
#
# What are the limitations of PSLNMD? What is improved in PSLNMAD?

# %% [markdown]
# ## 想定解答 / Expected answers
#
# **1** 輸送行列を使うことで、多数の box 間輸送を統一的に表現し、Python では `F @ C` の形で計算できる。
#
# Using a transport matrix allows many box-to-box transports to be represented consistently and computed as `F @ C`.
#
# **2** N は沈み込みの入口なので、染料は M を経由して D に運ばれる。
#
# N is the entrance of sinking, so dye is transported through M into D.
#
# **3** Ideal Age が大きいほど大気から長く隔離され、14C が放射壊変するため Δ14C は低くなる。
#
# Larger Ideal Age means longer isolation from the atmosphere, allowing more radioactive decay of 14C.
#
# **4** 表層では DIC が減少し、内部では再無機化により DIC と PO4 が増え、O2 は減少する。
#
# Surface DIC decreases, while remineralization increases DIC and PO4 and decreases O2 in the interior.
#
# **5** PSLNMD は深層を 1 box として扱う。PSLNMAD では北大西洋起源深層水 A を独立させ、深層循環をより現実的に表現する。

# %% [markdown]
# ## 次へ / Next
#
# 次章では **PSLNMAD (7-box model)** を学びます。
#
# The next chapter introduces the **PSLNMAD (7-box)** model.
#
# 追加される A box (North Atlantic Deep Water pathway) により、深層循環と炭素循環をより詳細に表現できるようになります。
